# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\rushi\\Desktop\\DPL\\predict2023_1.csv")
df.head(10)
# Out:
#    Unnamed: 0        Date   Time            Comp         Round  Day Venue  \
# 0           1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away
# 1           2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home
# 2           3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away
# 3           4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home
# 4           5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home
# 5           6  2022-09-03  17:30  Premier League   Matchweek 6  Sat  Away
# 6           9  2022-09-17  12:30  Premier League   Matchweek 8  Sat  Away
# 7          10  2022-10-02  14:00  Premier League   Matchweek 9  Sun  Home
# 8          12  2022-10-08  15:00  Premier League  Matchweek 10  Sat  Home
# 9          14  2022-10-16  16:30  Premier League  Matchweek 11  Sun  Away
#
#   Result  GF  GA  ...  Match Report  Notes    Sh   SoT  Dist   FK PK PKatt  \
# 0      W   2   0  ...  Match Report    NaN  13.0   1.0  18.7  1.0  1     1
# ...

# %%
df=df.drop('Notes',axis=1)
df.head(10)
# Out:
#    Unnamed: 0        Date   Time            Comp         Round  Day Venue  \
# 0           1  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away
# 1           2  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home
# 2           3  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away
# 3           4  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home
# 4           5  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home
# 5           6  2022-09-03  17:30  Premier League   Matchweek 6  Sat  Away
# 6           9  2022-09-17  12:30  Premier League   Matchweek 8  Sat  Away
# 7          10  2022-10-02  14:00  Premier League   Matchweek 9  Sun  Home
# 8          12  2022-10-08  15:00  Premier League  Matchweek 10  Sat  Home
# 9          14  2022-10-16  16:30  Premier League  Matchweek 11  Sun  Away
#
#   Result  GF  GA  ...         Referee  Match Report    Sh   SoT  Dist   FK PK  \
# ...

# %%
df=df.drop('Unnamed: 0',axis=1)
df=df.drop('Match Report',axis=1)
df.head(10)
# Out:
#          Date   Time            Comp         Round  Day Venue Result  GF  GA  \
# 0  2022-08-07  16:30  Premier League   Matchweek 1  Sun  Away      W   2   0
# 1  2022-08-13  15:00  Premier League   Matchweek 2  Sat  Home      W   4   0
# 2  2022-08-21  16:30  Premier League   Matchweek 3  Sun  Away      D   3   3
# 3  2022-08-27  15:00  Premier League   Matchweek 4  Sat  Home      W   4   2
# 4  2022-08-31  19:30  Premier League   Matchweek 5  Wed  Home      W   6   0
# 5  2022-09-03  17:30  Premier League   Matchweek 6  Sat  Away      D   1   1
# 6  2022-09-17  12:30  Premier League   Matchweek 8  Sat  Away      W   3   0
# 7  2022-10-02  14:00  Premier League   Matchweek 9  Sun  Home      W   6   3
# 8  2022-10-08  15:00  Premier League  Matchweek 10  Sat  Home      W   4   0
# 9  2022-10-16  16:30  Premier League  Matchweek 11  Sun  Away      L   0   1
#
#           Opponent  ...  Formation         Referee    Sh   SoT  Dist   FK PK  \
# ...

# %%
#This plot shows the time series analysis between goals for and time which can be used to provide
# valuable insights into historical performance, which can be leveraged for predictions, strategic planning, and a deeper
# understanding of the dynamics of Premier League matches.
df['Date'] = pd.to_datetime(df['Date'])

# Sort the DataFrame by 'Date' for a chronological order
df = df.sort_values(by='Date')

# Create a time series plot
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['GF'], marker='o', linestyle='-')
plt.title('Time Series Analysis: Goals For (GF) Over Time')
plt.xlabel('Date')
plt.ylabel('Goals For (GF)')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for readability

# Show the plot
plt.show()

# %%
team_goals = df.groupby('Team')['GF'].sum().reset_index()

# Sort the data by total goals scored in descending order
team_goals = team_goals.sort_values(by='GF', ascending=False)

# Create a bar plot to show how much each team has scored
plt.figure(figsize=(12, 6))
sns.barplot(x='GF', y='Team', data=team_goals, palette='colorblind') #colorblind is color palette specially used for presentation.
plt.title('Total Goals Scored by Each Team')
plt.xlabel('Total Goals For (GF)')
plt.ylabel('Team')

# Show the plot
plt.show()

# %%
# In this plot we come to know that results are also affected by the venue which can be a point for predicting.
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
sns.countplot(x='Venue', hue='Result', data=df, hue_order=['W', 'L'], palette='Set2')
plt.title('Venue vs. Results for Each Team')
plt.xlabel('Venue')
plt.ylabel('Count')

# Show the plot
plt.legend(title='Result')
plt.show()

# %%
df['Team']=df['Team'].replace("Wolverhampton Wanderers","Wolves")

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# Plot for Goals For (GF)
sns.barplot(x='GF', y='Team', data=df, palette='colorblind', ax=axes[0])
axes[0].set_title('Goals For (GF)')
axes[0].set_xlabel('Goals For (GF)')
axes[0].set_ylabel('Team')

# Plot for Goals Against (GA)
sns.barplot(x='GA', y='Team', data=df, palette='colorblind', ax=axes[1])
axes[1].set_title('Goals Against (GA)')
axes[1].set_xlabel('Goals Against (GA)')
axes[1].set_ylabel('')

# Adjust spacing between subplots
plt.tight_layout()

# Show the plots
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['xG'], df['Poss'], c='blue', marker='o')
plt.title('xG vs. Possession')
plt.xlabel('Expected Goals (xG)')
plt.ylabel('Possession (%)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['xGA'], df['Poss'], c='red', marker='o')
plt.title('Scatter Plot: xGA vs. Possession')
plt.xlabel('xGA (Expected Goals Against)')
plt.ylabel('Possession')
plt.grid(True)

# Show the plot
plt.show()

# %%
df.head(10)
# Out:
#           Date   Time            Comp        Round  Day Venue Result  GF  GA  \
# 38  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W   2   0
# 380 2022-08-05  20:00  Premier League  Matchweek 1  Fri  Home      L   0   2
# 684 2022-08-06  15:00  Premier League  Matchweek 1  Sat  Home      W   2   1
# 456 2022-08-06  15:00  Premier League  Matchweek 1  Sat  Away      L   1   2
# 722 2022-08-06  15:00  Premier League  Matchweek 1  Sat  Away      L   1   4
# 228 2022-08-06  15:00  Premier League  Matchweek 1  Sat  Away      L   0   2
# 532 2022-08-06  15:00  Premier League  Matchweek 1  Sat  Home      W   2   0
# 570 2022-08-06  15:00  Premier League  Matchweek 1  Sat  Away      L   0   2
# 418 2022-08-06  17:30  Premier League  Matchweek 1  Sat  Away      W   1   0
# 342 2022-08-06  12:30  Premier League  Matchweek 1  Sat  Home      D   2   2
#
#            Opponent  ...  Formation         Referee    Sh  SoT  Dist   FK PK  \
# ...

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='Result', y='xG', data=df, order=['L', 'D', 'W'], palette='Set2')
plt.title('xG vs. Result')
plt.xlabel('Result')
plt.ylabel('xG (Expected Goals)')

# Show the plot
plt.show()

# %%
df.isna().sum()
# Out:
# Date          0
# Time          0
# Comp          0
# Round         0
# Day           0
# Venue         0
# Result        0
# GF            0
# GA            0
# Opponent      0
# xG            0
# xGA           0
# Poss          0
# Attendance    2
# Captain       0
# Formation     0
# Referee       0
# Sh            0
# SoT           0
# Dist          0
# FK            0
# PK            0
# PKatt         0
# Season        0
# Team          0
# dtype: int64

# %%
df['Attendance'].fillna(method='ffill', inplace=True)  # Forward fill
df.isna().sum()
# Out:
# Date          0
# Time          0
# Comp          0
# Round         0
# Day           0
# Venue         0
# Result        0
# GF            0
# GA            0
# Opponent      0
# xG            0
# xGA           0
# Poss          0
# Attendance    0
# Captain       0
# Formation     0
# Referee       0
# Sh            0
# SoT           0
# Dist          0
# FK            0
# PK            0
# PKatt         0
# Season        0
# Team          0
# dtype: int64

# %%
df.dtypes
# Out:
# Date          datetime64[ns]
# Time                  object
# Comp                  object
# Round                 object
# Day                   object
# Venue                 object
# Result                object
# GF                     int64
# GA                     int64
# Opponent              object
# xG                   float64
# xGA                  float64
# Poss                 float64
# Attendance           float64
# Captain               object
# Formation             object
# Referee               object
# Sh                   float64
# SoT                  float64
# Dist                 float64
# FK                   float64
# PK                     int64
# PKatt                  int64
# Season                 int64
# Team                  object
# dtype: object

# %%
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
sns.countplot(x='Formation', hue='Result', data=df, order=df['Formation'].value_counts().index, palette='Set3')
plt.title('Formation vs. Result')
plt.xlabel('Formation')
plt.ylabel('Count')

# Show the plot
plt.legend(title='Result')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# C:\Users\rushi\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 9670 (\N{BLACK DIAMOND}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df.head()
# Out:
#           Date   Time            Comp        Round  Day Venue Result  GF  GA  \
# 38  2022-08-05  20:00  Premier League  Matchweek 1  Fri  Away      W   2   0
# 380 2022-08-05  20:00  Premier League  Matchweek 1  Fri  Home      L   0   2
# 684 2022-08-06  15:00  Premier League  Matchweek 1  Sat  Home      W   2   1
# 456 2022-08-06  15:00  Premier League  Matchweek 1  Sat  Away      L   1   2
# 722 2022-08-06  15:00  Premier League  Matchweek 1  Sat  Away      L   1   4
#
#            Opponent  ...  Formation         Referee    Sh  SoT  Dist   FK PK  \
# 38   Crystal Palace  ...      4-3-3  Anthony Taylor  10.0  2.0  14.6  1.0  0
# 380         Arsenal  ...    4-2-3-1  Anthony Taylor  10.0  2.0  14.2  0.0  0
# 684          Wolves  ...    4-2-3-1    Robert Jones  12.0  4.0  18.6  1.0  0
# 456    Leeds United  ...    4-2-3-1    Robert Jones  15.0  6.0  18.9  0.0  0
# 722       Tottenham  ...      5-3-2  Andre Marriner  10.0  2.0  17.1  0.0  0
#
#      PKatt  Season            Team
# ...

# %%
df1=pd.read_excel('/content/PL Table Prediction PDS.xlsx')
df1.head()
# Out:
#                 Team  Passes  Key Passes  Interceptions  Fouled  Fouls  \
# 0    Manchester City   659.8        12.3            5.9    10.1    9.1
# 1            Arsenal   538.2        11.7            6.2    11.4    9.8
# 2          Newcastle   422.4        11.5            8.8    10.5   10.7
# 3  Manchester United   502.3        12.6            9.3     7.8   11.2
# 4          Liverpool   589.5        12.1            8.8     8.4   10.7
#
#    CaughtOffside  Clearances  Saves  Shots  Goals  Assists  Possession Lost  \
# 0            1.3        10.3    1.6   15.8    2.5      1.8              7.8
# 1            1.5        14.9    2.5   15.6    2.3      1.7              9.9
# 2            1.9        17.0    2.5   15.0    1.8      1.1              9.6
# 3            2.1        19.3    2.6   15.6    1.5      1.1              7.7
# 4            2.2        14.2    2.9   15.9    2.0      1.5             10.9
#
#    Shots On Target  Yellow Cards
# 0              5.8           1.2
# ...

# %%
df1.corr()
# Out:
# <ipython-input-14-49b3fcfeb4d1>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                    Passes  Key Passes  Interceptions    Fouled     Fouls  \
# Passes           1.000000    0.834834      -0.645593 -0.050511 -0.279785
# Key Passes       0.834834    1.000000      -0.477445 -0.236571 -0.214469
# Interceptions   -0.645593   -0.477445       1.000000 -0.225197  0.267426
# Fouled          -0.050511   -0.236571      -0.225197  1.000000  0.134651
# Fouls           -0.279785   -0.214469       0.267426  0.134651  1.000000
# CaughtOffside    0.182315    0.320353       0.168929 -0.260556  0.126202
# Clearances      -0.876265   -0.823342       0.629146 -0.127813  0.265601
# Saves           -0.604905   -0.657480       0.345016  0.031785 -0.045200
# ...

# %%
corr_matrix = df1.corr()
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-27-5ebfeaf86782>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df1.corr()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(y='Passes', x='Team', data=df1, palette='colorblind')
plt.title('Possession Team Wise per 90 minutes')
plt.xlabel('Team')
plt.ylabel('Passes per 90')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(x='Passes', y='Shots', data=df1, hue='Team', palette='Set1')

# Add labels for each data point
for i in range(len(df1)):
    plt.text(df1['Passes'][i] + 0.2, df1['Shots'][i], df1['Team'][i], fontsize=8)

plt.title('Teamwise Passes vs Shots per game')
plt.xlabel('Passes')
plt.ylabel('Shots')
plt.legend(title='Team', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(x='Passes', y='Goals', data=df1, hue='Team', palette='Set1')

# Add labels for each data point
for i in range(len(df1)):
    plt.text(df1['Passes'][i] + 0.2, df1['Goals'][i], df1['Team'][i], fontsize=8)

plt.title('Teamwise Passes vs. Goals per game')
plt.xlabel('Passes')
plt.ylabel('Goals')
plt.legend(title='Team', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(x='Fouled', y='Yellow Cards', data=df1, hue='Team', palette='Set1')

# Add labels for each data point
for i in range(len(df1)):
    plt.text(df1['Fouled'][i] + 0.2, df1['Yellow Cards'][i], df1['Team'][i], fontsize=8)

plt.title('Teamwise Fouls Committed vs. Yellow Cards per game')
plt.xlabel('Fouled')
plt.ylabel('Yellow Cards')
plt.legend(title='Team', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(12, 8))

sns.scatterplot(x='Goals', y='Assists', data=df1, hue='Team', palette='Set1')
for i in range(len(df1)):
    plt.text(df1['Goals'][i] + 0.1, df1['Assists'][i], df1['Team'][i], fontsize=8)

plt.title('Teamwise Goals vs. Assists')
plt.xlabel('Goals')
plt.ylabel('Assists')
plt.legend(title='Team', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
